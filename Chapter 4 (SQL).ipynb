# %% [markdown]
# ### 4.1

# %% [markdown]
# #### a) Using the same sqlite database we were working with in this chapter, use SQL to make a DataFrame that's summarizes at bats, hits and homeruns at the player-game level. Make it only AL East Batters. It should have the following collums: date, team, opp, batter, n_atbats, hit, homerun. Rename hit and homerun to just H and HR respectively.

# %%
import pandas as pd
from os import path
import sqlite3

# %%
conn = sqlite3.connect('baseball.sqlite')

# %%
df = pd.read_sql(
    """
    SELECT date, player_game.team, player_game.opp, batter, n_atbats, hit AS H, homerun AS HR
    FROM player_game, game, team
    WHERE
        player_game.g_id = game.g_id AND
        player_game.team = team.teamID AND
        team.lgID = 'AL' AND
        team.divID = 'E'
    """, conn)

df
# Out:
#            date team  opp         batter  n_atbats    H   HR
# 0    2018-04-11  BAL  TOR        A.Jones         4  0.0  0.0
# 1    2018-04-11  BAL  TOR        C.Davis         4  2.0  0.0
# 2    2018-04-11  BAL  TOR       C.Gentry         4  0.0  0.0
# 3    2018-04-11  BAL  TOR        C.Sisco         4  2.0  0.0
# 4    2018-04-11  BAL  TOR       J.Schoop         4  2.0  0.0
# ..          ...  ...  ...            ...       ...  ...  ...
# 348  2018-09-17  TOR  BAL  L.Gurriel Jr.         4  1.0  0.0
# 349  2018-09-17  TOR  BAL      R.Grichuk         4  0.0  0.0
# 350  2018-09-17  TOR  BAL       R.Tellez         3  1.0  0.0
# 351  2018-09-17  TOR  BAL        R.Urena         3  0.0  0.0
# 352  2018-09-17  TOR  BAL      Y.Solarte         3  0.0  0.0
#
# [353 rows x 7 columns]

# %% [markdown]
# #### b) Now modify your query so that instead of batter you have first_name and last_name from the player table. Use abbreviation too (t for the team table, pg for player_game, etc)

# %%
df = pd.read_sql(
    """
    SELECT date, pg.team, pg.opp, p.first_name, p.last_name, n_atbats, hit AS H, homerun AS HR
    FROM player_game AS pg, game AS g, team AS t, player AS p
    WHERE
        pg.g_id = g.g_id AND
        pg.team = t.teamID AND
        p.id = pg.batter_id AND
        t.lgID = 'AL' AND
        t.divID = 'E'
    """, conn)

df
# Out:
#            date team  opp first_name    last_name  n_atbats    H   HR
# 0    2018-04-11  BAL  TOR       Adam        Jones         4  0.0  0.0
# 1    2018-04-15  BAL  BOS       Adam        Jones         4  0.0  0.0
# 2    2018-05-12  BAL  TBA       Adam        Jones         4  1.0  0.0
# 3    2018-05-29  BAL  WAS       Adam        Jones         4  2.0  0.0
# 4    2018-05-30  BAL  WAS       Adam        Jones         4  1.0  0.0
# ..          ...  ...  ...        ...          ...       ...  ...  ...
# 348  2018-09-07  TOR  CLE    Aledmys         Diaz         4  0.0  0.0
# 349  2018-09-17  TOR  BAL    Aledmys         Diaz         1  1.0  1.0
# 350  2018-09-01  TOR  MIA    Lourdes  Gurriel Jr.         4  1.0  0.0
# 351  2018-09-07  TOR  CLE    Lourdes  Gurriel Jr.         5  0.0  0.0
# 352  2018-09-17  TOR  BAL    Lourdes  Gurriel Jr.         4  1.0  0.0
#
# [353 rows x 8 columns]

# %% [markdown]
# ### 4.2

# %% [markdown]
# #### Using the same sqlite database, make a DataFrame that's the game table, with two new columsn: 'home_full' and 'away_full' that have the full names of the teams (e.g. New York Yankees, Milwaukee Brewers)

# %%
df = pd.read_sql(
    """
    SELECT g.*, th.name as home_full, ta.name as away_full
    FROM game AS g, team AS th, team AS ta
    WHERE
        g.home_team = th.teamID AND
        g.away_team = ta.teamID
    """, conn)

df.head()
# Out:
#         g_id home_team away_team        date  home_final_score  \
# 0  201800050       CIN       WAS  2018-04-01                 5
# 1  201800073       NYA       TBA  2018-04-03                11
# 2  201800099       COL       ATL  2018-04-06                 3
# 3  201800115       PHI       MIA  2018-04-07                20
# 4  201800122       SLN       ARI  2018-04-08                 1
#
#    away_final_score start_time                venue_name      umpire_1B  \
# 0                 6    4:10 PM  Great American Ball Park     James Hoye
# 1                 4    4:19 PM            Yankee Stadium       Joe West
# 2                 8    3:11 PM               Coors Field     Bill Welke
# 3                 1    6:08 PM        Citizens Bank Park  Carlos Torres
# 4                 4    1:15 PM             Busch Stadium      Rob Drake
#
#          umpire_2B      umpire_3B       umpire_HP                    weather  \
# ...
